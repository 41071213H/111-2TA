# %%
import pandas as pd
df = pd.read_csv("hellopython2.csv")

# %%
print(df)
print(df.info())
# Out:
#     NO  gender  yearsold  prefer   cm  wt size
# 0    1    male      22.0    nike  170  70   XL
# 1    2    male      18.0  adidas  166  65    M
# 2    3  female      19.0    puma  171  56    M
# 3    4  female      21.0    puma  168  60    L
# 4    5    male      23.0     NaN  170  70    L
# 5    6    male      22.0    nike  175  72  NaN
# 6    7    male      18.0  adidas  168  70    L
# 7    8  female       NaN    nike  166  63    L
# 8    9  female      21.0  adidas  164  55    M
# 9   10  female      20.0  adidas  164  52    M
# 10  11  female      21.0    puma  168  60    L
# 11  12    male      23.0     NaN  170  70    L
# 12  13    male      22.0    nike  175  72  NaN
# 13  14  female       NaN    nike  166  63    L
# 14  15  female      21.0  adidas  164  55    M
# 15  16  female      21.0  adidas  164  55    M
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ...

# %%
df['gender'] = df['gender'].map({'male':"boy",'female':"girl"})
print(df)
print("+++++++++")
print(df.info())
# Out:
#     NO gender  yearsold  prefer   cm  wt size
# 0    1    boy      22.0    nike  170  70   XL
# 1    2    boy      18.0  adidas  166  65    M
# 2    3   girl      19.0    puma  171  56    M
# 3    4   girl      21.0    puma  168  60    L
# 4    5    boy      23.0     NaN  170  70    L
# 5    6    boy      22.0    nike  175  72  NaN
# 6    7    boy      18.0  adidas  168  70    L
# 7    8   girl       NaN    nike  166  63    L
# 8    9   girl      21.0  adidas  164  55    M
# 9   10   girl      20.0  adidas  164  52    M
# 10  11   girl      21.0    puma  168  60    L
# 11  12    boy      23.0     NaN  170  70    L
# 12  13    boy      22.0    nike  175  72  NaN
# 13  14   girl       NaN    nike  166  63    L
# 14  15   girl      21.0  adidas  164  55    M
# 15  16   girl      21.0  adidas  164  55    M
# +++++++++
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ...

# %%
k = df[df["yearsold"]>=21]
k
# Out:
#     NO gender  yearsold  prefer   cm  wt size
# 0    1    boy      22.0    nike  170  70   XL
# 3    4   girl      21.0    puma  168  60    L
# 4    5    boy      23.0     NaN  170  70    L
# 5    6    boy      22.0    nike  175  72  NaN
# 8    9   girl      21.0  adidas  164  55    M
# 10  11   girl      21.0    puma  168  60    L
# 11  12    boy      23.0     NaN  170  70    L
# 12  13    boy      22.0    nike  175  72  NaN
# 14  15   girl      21.0  adidas  164  55    M
# 15  16   girl      21.0  adidas  164  55    M

# %%
new_df = df.sort_values(["cm"],ascending = True)
print(new_df)
# Out:
#     NO gender  yearsold  prefer   cm  wt size
# 8    9   girl      21.0  adidas  164  55    M
# 9   10   girl      20.0  adidas  164  52    M
# 14  15   girl      21.0  adidas  164  55    M
# 15  16   girl      21.0  adidas  164  55    M
# 1    2    boy      18.0  adidas  166  65    M
# 7    8   girl       NaN    nike  166  63    L
# 13  14   girl       NaN    nike  166  63    L
# 3    4   girl      21.0    puma  168  60    L
# 6    7    boy      18.0  adidas  168  70    L
# 10  11   girl      21.0    puma  168  60    L
# 0    1    boy      22.0    nike  170  70   XL
# 4    5    boy      23.0     NaN  170  70    L
# 11  12    boy      23.0     NaN  170  70    L
# 2    3   girl      19.0    puma  171  56    M
# 5    6    boy      22.0    nike  175  72  NaN
# 12  13    boy      22.0    nike  175  72  NaN

# %%
n_df = new_df.reset_index(inplace=False,drop=True)
n_df
# Out:
#     NO gender  yearsold  prefer   cm  wt size
# 0    9   girl      21.0  adidas  164  55    M
# 1   10   girl      20.0  adidas  164  52    M
# 2   15   girl      21.0  adidas  164  55    M
# 3   16   girl      21.0  adidas  164  55    M
# 4    2    boy      18.0  adidas  166  65    M
# 5    8   girl       NaN    nike  166  63    L
# 6   14   girl       NaN    nike  166  63    L
# 7    4   girl      21.0    puma  168  60    L
# 8    7    boy      18.0  adidas  168  70    L
# 9   11   girl      21.0    puma  168  60    L
# 10   1    boy      22.0    nike  170  70   XL
# 11   5    boy      23.0     NaN  170  70    L
# 12  12    boy      23.0     NaN  170  70    L
# 13   3   girl      19.0    puma  171  56    M
# 14   6    boy      22.0    nike  175  72  NaN
# 15  13    boy      22.0    nike  175  72  NaN

# %%
df5 = pd.read_csv("hellopython2.csv")
df6 = pd.read_csv("hellopython3.csv")
df56 = df5.append(df6)
df56
# Out:
# /var/folders/kr/jqz14bp50n5gp8c42p_h8rnh0000gn/T/ipykernel_18768/292482593.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df56 = df5.append(df6)
#     NO  gender  yearsold  prefer   cm  wt size
# 0    1    male      22.0    nike  170  70   XL
# 1    2    male      18.0  adidas  166  65    M
# 2    3  female      19.0    puma  171  56    M
# 3    4  female      21.0    puma  168  60    L
# 4    5    male      23.0     NaN  170  70    L
# 5    6    male      22.0    nike  175  72  NaN
# 6    7    male      18.0  adidas  168  70    L
# 7    8  female       NaN    nike  166  63    L
# 8    9  female      21.0  adidas  164  55    M
# 9   10  female      20.0  adidas  164  52    M
# 10  11  female      21.0    puma  168  60    L
# 11  12    male      23.0     NaN  170  70    L
# 12  13    male      22.0    nike  175  72  NaN
# 13  14  female       NaN    nike  166  63    L
# ...

# %%
df_new = df56.reset_index(inplace=False,drop=True)
df_new
# Out:
#     NO  gender  yearsold  prefer   cm  wt size
# 0    1    male      22.0    nike  170  70   XL
# 1    2    male      18.0  adidas  166  65    M
# 2    3  female      19.0    puma  171  56    M
# 3    4  female      21.0    puma  168  60    L
# 4    5    male      23.0     NaN  170  70    L
# 5    6    male      22.0    nike  175  72  NaN
# 6    7    male      18.0  adidas  168  70    L
# 7    8  female       NaN    nike  166  63    L
# 8    9  female      21.0  adidas  164  55    M
# 9   10  female      20.0  adidas  164  52    M
# 10  11  female      21.0    puma  168  60    L
# 11  12    male      23.0     NaN  170  70    L
# 12  13    male      22.0    nike  175  72  NaN
# 13  14  female       NaN    nike  166  63    L
# 14  15  female      21.0  adidas  164  55    M
# 15  16  female      21.0  adidas  164  55    M
# 16   1    male      18.0  adidas  168  70    L
# 17   2  female      22.0    nike  166  63    L
# 18   3  female      21.0  adidas  164  55    M
# ...

# %%
left = pd.read_csv('mergeleft.csv')
right = pd.read_csv("mergeleft.csv")
plus = pd.merge(left,right,on='NO',how="inner")
plus
# Out:
#    NO gender_x  yearsold_x prefer_x  cm_x gender_y  yearsold_y prefer_y  cm_y
# 0   1     male          18   adidas   168     male          18   adidas   168
# 1   2   female          22     nike   166   female          22     nike   166
# 2   3   female          21   adidas   164   female          21   adidas   164
# 3   4   female          21     puma   168   female          21     puma   168
# 4   5     male          23     nike   170     male          23     nike   170
# 5   6     male          22     nike   175     male          22     nike   175
# 6   7   female          21     puma   168   female          21     puma   168
# 7   8     male          23     puma   170     male          23     puma   170
# 8   9     male          22     nike   175     male          22     nike   175
# 9  10   female          20   adidas   164   female          20   adidas   164

# %%
left = pd.read_csv('mergeleft.csv')
right = pd.read_csv("mergeleft.csv")
plus = pd.merge(left,right,on='NO',how="outer")
plus
# Out:
#    NO gender_x  yearsold_x prefer_x  cm_x gender_y  yearsold_y prefer_y  cm_y
# 0   1     male          18   adidas   168     male          18   adidas   168
# 1   2   female          22     nike   166   female          22     nike   166
# 2   3   female          21   adidas   164   female          21   adidas   164
# 3   4   female          21     puma   168   female          21     puma   168
# 4   5     male          23     nike   170     male          23     nike   170
# 5   6     male          22     nike   175     male          22     nike   175
# 6   7   female          21     puma   168   female          21     puma   168
# 7   8     male          23     puma   170     male          23     puma   170
# 8   9     male          22     nike   175     male          22     nike   175
# 9  10   female          20   adidas   164   female          20   adidas   164

# %%
import pandas as pd
df = pd.read_csv('py01nsc2011.csv')
print(df.columns)
# Out:
# Index(['NO', 'Gender', 'Bornyear', 'Race', 'Player', 'Sportyear', 'Bestpride',
#        'Income', 'PrantEdu', 'PersonalEdu', 'WantJob', 'SS01', 'SS02', 'SS03',
#        'SS04', 'SS05', 'SS06', 'SS07', 'SS08', 'SS09', 'SS10', 'SS11', 'SS12',
#        'SS13', 'SS14', 'SS15', 'SS16', 'SS17', 'SS18', 'SS19', 'SS20', 'CB01',
#        'CB02', 'CB03', 'CB04', 'CB05', 'CB06', 'CB07', 'CB08', 'CD01', 'CD02',
#        'CD03', 'CD04', 'CD05', 'CD06', 'CD07', 'CD08', 'CD09', 'CD10'],
#       dtype='object')

# %%
print("最大值",df["Sportyear"].max())
print("最小值",df["Sportyear"].min())
print("平均數",df["Sportyear"].mean())
print("標準差",df["Sportyear"].std())
print("次數",df.value_counts(["Sportyear"]))
# Out:
# 最大值 20.0
# 最小值 0.0
# 平均數 7.501766784452297
# 標準差 3.347004147459472
# 次數 Sportyear
# 6.0          210
# 10.0         176
# 8.0          160
# 5.0          141
# 3.0          138
# 7.0          114
# 9.0          108
# 12.0          87
# 4.0           78
# 11.0          54
# 13.0          48
# 0.0           32
# 14.0          30
# 15.0          14
# 2.0            6
# 1.0            6
# 16.0           5
# 17.0           2
# 18.0           2
# 20.0           2
# 0.5            1
# 13.5           1
# dtype: int64

# %%
print(df["Gender"].describe())
print("=====")
print(df["Sportyear"].describe())
# Out:
# count     1423
# unique       2
# top       male
# freq       942
# Name: Gender, dtype: object
# =====
# count    1415.000000
# mean        7.501767
# std         3.347004
# min         0.000000
# 25%         5.000000
# 50%         7.000000
# 75%        10.000000
# max        20.000000
# Name: Sportyear, dtype: float64

# %%
print(df[:].describe())
# Out:
#                  NO     Bornyear         Race       Player    Sportyear  \
# count   1423.000000  1423.000000  1371.000000  1423.000000  1415.000000
# mean   15219.482783    79.621223     1.333333     0.229093     7.501767
# std     4994.366801     2.161034     0.658835     2.645660     3.347004
# min    10001.000000    66.000000     1.000000     0.000000     0.000000
# 25%    10356.500000    78.000000     1.000000     0.000000     5.000000
# 50%    10712.000000    81.000000     1.000000     0.000000     7.000000
# 75%    20336.500000    82.000000     1.000000     0.000000    10.000000
# max    20692.000000    84.000000     3.000000    99.000000    20.000000
#
#          Bestpride       Income     PrantEdu  PersonalEdu      WantJob  ...  \
# count  1423.000000  1423.000000  1423.000000  1423.000000  1423.000000  ...
# mean      2.169361     2.682361     4.063949     3.324666     0.949403  ...
# std       5.187089     9.968249     9.184818     8.860697     5.228691  ...
# ...

# %%
print(df)
# Out:
#          NO  Gender  Bornyear  Race  Player  Sportyear  Bestpride  Income  \
# 0     10001    male        81   1.0       0        6.0          2       2
# 1     10002    male        81   1.0       0        6.0          3       1
# 2     10003    male        82   1.0       0        6.0          2       2
# 3     10004    male        81   1.0       0        6.0          2       1
# 4     10005    male        82   1.0       0        8.0          2       1
# ...     ...     ...       ...   ...     ...        ...        ...     ...
# 1418  20688  female        80   3.0       0       10.0          2       3
# 1419  20689  female        80   1.0       0        3.0          1       2
# 1420  20690    male        79   1.0       0       12.0          2       1
# 1421  20691    male        80   2.0       0        3.0          2       1
# 1422  20692    male        80   1.0       0        2.0          3       2
#
#       PrantEdu  PersonalEdu  ...  CD01  CD02  CD03  CD04  CD05  CD06  CD07  \
# ...

# %%
#把橫向的數值相加成新的一個
x1 = ["SS01","SS02","SS03","SS04"]
df["SST1"] = df[x1].sum(axis = 'columns')
print(df["SST1"].describe())
print(df["SST1"])
# Out:
# count    1423.000000
# mean       14.841181
# std         3.013578
# min         4.000000
# 25%        13.000000
# 50%        15.000000
# 75%        17.000000
# max        20.000000
# Name: SST1, dtype: float64
# 0       13
# 1       18
# 2       14
# 3       15
# 4       19
#         ..
# 1418    20
# 1419    14
# 1420    11
# 1421    11
# 1422    14
# Name: SST1, Length: 1423, dtype: int64

# %%
print(df[x1].mean())
df["SST1M"] = df[x1].mean(axis = 1)
print(df["SST1M"].mean())
print(df['SST1M'].describe())
# Out:
# SS01    3.176388
# SS02    3.955727
# SS03    4.014055
# SS04    3.695011
# dtype: float64
# 3.710295151089248
# count    1423.000000
# mean        3.710295
# std         0.753394
# min         1.000000
# 25%         3.250000
# 50%         3.750000
# 75%         4.250000
# max         5.000000
# Name: SST1M, dtype: float64

# %%
#儲存成新的檔案
df.to_csv('py01nsc2011_1.csv')
df1 = pd.read_csv("py01nsc2011_1.csv")
print(df1.columns)
# Out:
# Index(['Unnamed: 0', 'NO', 'Gender', 'Bornyear', 'Race', 'Player', 'Sportyear',
#        'Bestpride', 'Income', 'PrantEdu', 'PersonalEdu', 'WantJob', 'SS01',
#        'SS02', 'SS03', 'SS04', 'SS05', 'SS06', 'SS07', 'SS08', 'SS09', 'SS10',
#        'SS11', 'SS12', 'SS13', 'SS14', 'SS15', 'SS16', 'SS17', 'SS18', 'SS19',
#        'SS20', 'CB01', 'CB02', 'CB03', 'CB04', 'CB05', 'CB06', 'CB07', 'CB08',
#        'CD01', 'CD02', 'CD03', 'CD04', 'CD05', 'CD06', 'CD07', 'CD08', 'CD09',
#        'CD10', 'SST1', 'SST1M'],
#       dtype='object')

# %%
print(df1)
# Out:
#       Unnamed: 0     NO  Gender  Bornyear  Race  Player  Sportyear  Bestpride  \
# 0              0  10001    male        81   1.0       0        6.0          2
# 1              1  10002    male        81   1.0       0        6.0          3
# 2              2  10003    male        82   1.0       0        6.0          2
# 3              3  10004    male        81   1.0       0        6.0          2
# 4              4  10005    male        82   1.0       0        8.0          2
# ...          ...    ...     ...       ...   ...     ...        ...        ...
# 1418        1418  20688  female        80   3.0       0       10.0          2
# 1419        1419  20689  female        80   1.0       0        3.0          1
# 1420        1420  20690    male        79   1.0       0       12.0          2
# 1421        1421  20691    male        80   2.0       0        3.0          2
# 1422        1422  20692    male        80   1.0       0        2.0          3
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("python2011nsc.csv")
df
# Out:
#       NO  Gender  DateOfBirth  Race  FaEdu  MomEdu  FaexpEdu  CoexpEdu  \
# 0      1       1           84     1      4       2         2         2
# 1      2       1           84     1      3       2         2         2
# 2      3       1           84     1      1       2         2         2
# 3      4       1           83     1      2       2         2         2
# 4      5       1           84     3      4       4         2         2
# ..   ...     ...          ...   ...    ...     ...       ...       ...
# 525  526       1           83     1      3       3         2         2
# 526  527       1           84     1      3       3         2         2
# 527  528       1           84     1      2       2         2         2
# 528  529       1           84     1      4       3         2         2
# 529  530       1           84     3      3       3         2         2
#
#      Income  Grade  ...  c8  c9  c10        pl    al        ss        tr  \
# ...

# %%
plt.plot(df["Grade"])
plt.show()

# %%
plt.plot(df["Grade"])
plt.show()

# %%
x = [0,1]
gender = [389,141]
plt.bar(x,gender,color ="red")
plt.xticks(x,["male","female"])
plt.show()

# %%
df["Gender"].value_counts().plot.bar(rot=45,colormap="summer")
# Out:
# <AxesSubplot:>

# %%
size = df["Gender"].value_counts()
labels = ["female","male"]
plt.pie(size,labels = labels, autopct = "%.1f%%")
plt.axis("equal")
print(size)
plt.show()
# Out:
# 1    389
# 0    141
# Name: Gender, dtype: int64

# %%
df["Gender"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 525    1
# 526    1
# 527    1
# 528    1
# 529    1
# Name: Gender, Length: 530, dtype: int64

# %%
plt.hist(df['Grade'],20)
plt.show()

# %%
plt.scatter(df["ss"], df["achievement"], color='r',alpha=.5)
plt.show()

# %%
plt.plot([0,1,4],[1,4,7],marker="1")
plt.show()

# %%
fig , ax = plt.subplots(1)
ax.plot([1,3,5,7],[2,4,2,5],label = "line1")
ax.plot([1,2,5,8],[3,4,1,5],label = "line2")
ax.legend()
